# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
from api_keys import weather_api_key

from citipy import citipy
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
BASE_URL = "https://api.geoapify.com/v2/places"
HTTP_STATUS_OK = 200
HTTP_STATUS_NOT_FOUND = 404

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        chonchi -42.6128  -73.8092     16.73        53          21
# 1        1         albany  42.6001  -73.9662      3.23        67         100
# 2        2  blackmans bay -43.0167  147.3167     20.96        64          83
# 3        3        selfoss  63.9331  -20.9971     -5.26        89          99
# 4        4         kodiak  57.7900 -152.4072      4.73        87         100
#
#    Wind Speed Country        Date
# 0        1.72      CL  1707778011
# 1        0.45      US  1707777803
# 2        0.45      AU  1707778012
# 3        4.89      IS  1707778013
# 4        6.17      US  1707778013

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather = city_data_df[
    (city_data_df["Wind Speed"] <= 5) & (city_data_df["Humidity"] < 50) &(city_data_df["Cloudiness"] < 50) & (city_data_df["Max Temp"] > 21) & (city_data_df["Max Temp"] < 40)
]

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
ideal_weather
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 45        45           new norfolk -42.7826  147.0587     21.62        28
# 95        95                 adrar  20.5022  -10.0711     23.62        26
# 103      103               kassala  15.4510   36.4000     24.20        34
# 143      143               biltine  14.5333   20.9167     22.57        10
# 145      145               jwaneng -24.6004   24.7303     22.03        43
# 170      170             santa ana  33.7456 -117.8678     22.10        42
# 248      248    ciudad insurgentes  25.2625 -111.7753     23.73        16
# 320      320              tidjikja  18.5564  -11.4271     26.81        26
# 322      322            bairnsdale -37.8333  147.6167     32.81        42
# 328      328                freire -38.9500  -72.6333     26.89        39
# 354      354                 kidal  18.4411    1.4078     25.12         8
# 376      376  villa de san antonio  14.3167  -87.6167     31.39        39
# 411      411        tchintabaraden  15.8969    5.7985     24.24         8
# 418      418              langtang   9.1333    9.7833     27.47        15
# 488      488               mochudi -24.4167   26.1500     21.87        46
# 489      489             maiduguri  11.8464   13.1603     24.10         9
# 499      499                ghanzi -21.5667   21.7833     24.11        43
# 502      502               reggane  26.7158    0.1714     22.99        25
# 536      536                   alo   7.4178    6.7371     31.03        29
# 547      547               mirriah  13.7073    9.1501     22.65         9
#
#      Cloudiness  Wind Speed Country        Date
# 45           23        1.55      AU  1707778036
# 95            0        4.04      MR  1707778068
# 103           4        3.53      SD  1707778074
# 143           0        4.34      TD  1707778108
# 145          32        4.42      BW  1707778110
# 170           0        4.63      US  1707778065
# 248           6        3.07      MX  1707778180
# 320           0        4.27      MR  1707778242
# 322           1        2.68      AU  1707778243
# 328           0        4.12      CL  1707778247
# 354           0        4.03      ML  1707778265
# 376          26        2.36      HN  1707778280
# 411           0        4.10      NE  1707778311
# 418           0        2.88      NG  1707778316
# 488           0        1.17      BW  1707778368
# 489           0        3.42      NG  1707778368
# 499           0        3.78      BW  1707778378
# 502           0        3.22      DZ  1707778097
# 536           0        1.02      NG  1707778406
# 547           1        4.24      NE  1707778413

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
copy_ideal_weather = ideal_weather.copy()
hotel_df = copy_ideal_weather[["City","Country","Lat","Lng","Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = " "

# Display sample data
hotel_df
# Out:
# C:\Users\macol\AppData\Local\Temp\ipykernel_16416\3675416011.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = " "
#                      City Country      Lat       Lng  Humidity Hotel Name
# 45            new norfolk      AU -42.7826  147.0587        28
# 95                  adrar      MR  20.5022  -10.0711        26
# 103               kassala      SD  15.4510   36.4000        34
# 143               biltine      TD  14.5333   20.9167        10
# 145               jwaneng      BW -24.6004   24.7303        43
# 170             santa ana      US  33.7456 -117.8678        42
# 248    ciudad insurgentes      MX  25.2625 -111.7753        16
# 320              tidjikja      MR  18.5564  -11.4271        26
# 322            bairnsdale      AU -37.8333  147.6167        42
# 328                freire      CL -38.9500  -72.6333        39
# 354                 kidal      ML  18.4411    1.4078         8
# 376  villa de san antonio      HN  14.3167  -87.6167        39
# 411        tchintabaraden      NE  15.8969    5.7985         8
# 418              langtang      NG   9.1333    9.7833        15
# 488               mochudi      BW -24.4167   26.1500        46
# 489             maiduguri      NG  11.8464   13.1603         9
# 499                ghanzi      BW -21.5667   21.7833        43
# 502               reggane      DZ  26.7158    0.1714        25
# 536                   alo      NG   7.4178    6.7371        29
# 547               mirriah      NE  13.7073    9.1501         9

# %%
# test = 'https://api.geoapify.com/v2/places?categories=public_transport.subway&
#filter=circle:-0.07071648508463113,51.50848194136378,1000&bias=proximity:-0.07071648508463113,51.50848194136378&
#limit=20&apiKey=7aa85fddfbfe4c16994e21e24a66645f'
# next_test = requests.get(test).json()
params

# %%
test_hotel_list = ['london','new york']

# %%
# Set parameters to search for a hotel
radius = 10000
limit=20
categories="accommodation.hotel"

params = {
    "categories": categories,
    "radius": radius,
    "limit": limit,
    "apiKey": geoapify_key
}

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# %%
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df

# %%
name_address = requests.get(base_url, params=params)
name_address

# %%
test_cities = ["london","miami","berlin"]

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# %%
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(test_cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}units=metric&q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | london
# Processing Record 2 of Set 1 | miami
# Processing Record 3 of Set 1 | berlin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#      City      Lat      Lng
# 0  london  51.5085  -0.1257
# 1   miami  25.7743 -80.1937
# 2  berlin  52.5244  13.4105

# %%
city_data_df["Hotel Name"] = ""
city_data_df
# Out:
#      City      Lat      Lng Hotel Name
# 0  london  51.5085  -0.1257
# 1   miami  25.7743 -80.1937
# 2  berlin  52.5244  13.4105

# %%
# Set parameters to search for a hotel
radius = 10000
limit=20
categories="accommodation.hotel"

params = {
    "categories": categories,
    "limit": limit,
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in city_data_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = city_data_df.loc[index, "Lat"]
    longitude = city_data_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Make and API request using the params dictionaty
    response = requests.get(BASE_URL, params=params)
    status_code = response.status_code
    if status_code == HTTP_STATUS_OK:      
        # Convert the API response to JSON format
        name_address = response.json()

        # Grab the first hotel from the results and store the name in the hotel_df DataFrame
        try:
            city_data_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
        except (KeyError, IndexError):
            # If no hotel is found, set the hotel name as "No hotel found".
            city_data_df.loc[index, "Hotel Name"] = "No hotel found"

        # Log the search results
        print(f"{city_data_df.loc[index, 'City']} - nearest hotel: {city_data_df.loc[index, 'Hotel Name']}")
    elif status_code == HTTP_STATUS_NOT_FOUND:
        # If no hotel is found, set the hotel name as "No hotel found".
        city_data_df.loc[index, "Hotel Name"] = "No hotel found"
        print(f"No hotel found for {city}. url:{response.url}")
    else:
        msg = f"Invalid status code {status_code} for url {response.url}"
        raise ValueError(msg)
# Display sample data
city_data_df
# Out:
# Starting hotel search
# london - nearest hotel: The Clermont
# miami - nearest hotel: The Langford
# berlin - nearest hotel: Lux 11
#      City      Lat      Lng    Hotel Name
# 0  london  51.5085  -0.1257  The Clermont
# 1   miami  25.7743 -80.1937  The Langford
# 2  berlin  52.5244  13.4105        Lux 11

# %%
name_address
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Lux 11',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Rosa-Luxemburg-Straße',
#     'housenumber': '11-13',
#     'lon': 13.4098329,
#     'lat': 52.5245961,
#     'formatted': 'Lux 11, Rosa-Luxemburg-Straße 11-13, 10178 Berlin, Germany',
#     'address_line1': 'Lux 11',
#     'address_line2': 'Rosa-Luxemburg-Straße 11-13, 10178 Berlin, Germany',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Lux 11',
#       'rooms': 72,
#       'osm_id': 5656522306,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'no',
#       'addr:street': 'Rosa-Luxemburg-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+49 30 9362800',
#       'opening_hours': '24/7',
#       'contact:website': 'http://www.lux-eleven.com/',
#       'addr:housenumber': '11-13'}},
#     'distance': 50,
#     'place_id': '5151a62c9ed5d12a4059429808f725434a40f00103f90142ae2751010000009203064c7578203131'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4098329, 52.52459609908739]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Motel One',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10179',
#     'district': 'Mitte',
#     'neighbourhood': 'Spandauer Vorstadt',
#     'suburb': 'Mitte',
#     'street': 'Dircksenstraße',
#     'housenumber': '36',
#     'lon': 13.408614479025596,
#     'lat': 52.523232199999995,
#     'formatted': 'Motel One, Dircksenstraße 36, 10179 Berlin, Germany',
#     'address_line1': 'Motel One',
#     'address_line2': 'Dircksenstraße 36, 10179 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.building',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Motel One',
#       'brand': 'Motel One',
#       'osm_id': 23748095,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'operator': 'Motel One Berlin Hackescher Markt',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'check_date': '2023-03-18',
#       'wheelchair': 'yes',
#       'addr:street': 'Dircksenstraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10179,
#       'contact:phone': '+49 30 20054080',
#       'brand:wikidata': 'Q391080',
#       'brand:wikipedia': 'en:Motel One',
#       'building:levels': 7,
#       'contact:website': 'http://www.motel-one.com/de/hotels/hotels-berlin/hotel-berlin-alexanderplatz.html',
#       'addr:housenumber': 36,
#       'toilets:wheelchair': 'yes'}},
#     'distance': 159,
#     'place_id': '51871d239738d12a4059e1d8c98bf9424a40f00102f901ff5d6a01000000009203094d6f74656c204f6e65'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.408634875332394, 52.52324054103679]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Park Inn by Radisson Berlin-Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'housenumber': '7',
#     'lon': 13.412789245687765,
#     'lat': 52.52284,
#     'formatted': 'Park Inn by Radisson Berlin-Alexanderplatz, 7, 10178 Berlin, Germany',
#     'address_line1': 'Park Inn by Radisson Berlin-Alexanderplatz',
#     'address_line2': '7, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access',
#      'internet_access.for_customers'],
#     'details': ['details',
#      'details.accommodation',
#      'details.building',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Park Inn by Radisson Berlin-Alexanderplatz',
#       'brand': 'Park Inn',
#       'layer': 1,
#       'rooms': 1012,
#       'osm_id': 23723125,
#       'smoking': 'no',
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'osm_type': 'w',
#       'wikidata': 'Q701571',
#       'addr:city': 'Berlin',
#       'wikipedia': 'de:Park Inn by Radisson Berlin Alexanderplatz',
#       'addr:place': 'Alexanderplatz',
#       'roof:shape': 'flat',
#       'start_date': '1970-10-07',
#       'wheelchair': 'no',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+49 30 23890',
#       'brand:wikidata': 'Q60711675',
#       'brand:wikipedia': 'ru:Park Inn by Radisson',
#       'building:colour': 'SkyBlue',
#       'building:levels': 3,
#       'contact:website': 'https://www.parkinn-berlin.de/',
#       'internet_access': 'wlan',
#       'addr:housenumber': 7,
#       'contact:facebook': 'https://www.facebook.com/ParkInnBerlinAlexanderplatz',
#       'building:material': 'glass',
#       'contact:instagram': 'https://www.instagram.com/parkinn_berlin',
#       'wikimedia_commons': 'Category:Park Inn Berlin Alexanderplatz',
#       'contact:tripadvisor': 'https://www.tripadvisor.com/Hotel_Review-g187323-d230550-Reviews-Park_Inn_by_Radisson_Berlin_Alexanderplatz-Berlin.html?m=19905',
#       'internet_access:fee': 'customers'}},
#     'distance': 164,
#     'place_id': '51233654d859d32a40590d847c71ec424a40f00102f90175fc69010000000092032a5061726b20496e6e206279205261646973736f6e204265726c696e2d416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.412794838218423, 52.52284067706942]}},
#   {'type': 'Feature',
#    'properties': {'name': 'H2 Hotel Berlin-Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Karl-Liebknecht-Straße',
#     'housenumber': '32',
#     'lon': 13.4143711,
#     'lat': 52.5253146,
#     'formatted': 'H2 Hotel Berlin-Alexanderplatz, Karl-Liebknecht-Straße 32, 10178 Berlin, Germany',
#     'address_line1': 'H2 Hotel Berlin-Alexanderplatz',
#     'address_line2': 'Karl-Liebknecht-Straße 32, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'H2 Hotel Berlin-Alexanderplatz',
#       'osm_id': 1363463109,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Karl-Liebknecht-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+49 30 24088010',
#       'contact:website': 'http://www.h2-hotels.de/',
#       'internet_access': 'wlan',
#       'addr:housenumber': 32,
#       'air_conditioning': 'yes',
#       'toilets:wheelchair': 'yes'}},
#     'distance': 282,
#     'place_id': '51a9d0e57228d42a405987983f823d434a40f00103f901c5cb44510000000092031e483220486f74656c204265726c696e2d416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.414371099999999, 52.52531459908737]}},
#   {'type': 'Feature',
#    'properties': {'name': 'H4 Hotel Berlin-Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Karl-Liebknecht-Straße',
#     'housenumber': '32',
#     'lon': 13.4146506,
#     'lat': 52.5255613,
#     'formatted': 'H4 Hotel Berlin-Alexanderplatz, Karl-Liebknecht-Straße 32, 10178 Berlin, Germany',
#     'address_line1': 'H4 Hotel Berlin-Alexanderplatz',
#     'address_line2': 'Karl-Liebknecht-Straße 32, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'H4 Hotel Berlin-Alexanderplatz',
#       'rooms': 337,
#       'stars': 4,
#       'osm_id': 1169468049,
#       'tourism': 'hotel',
#       'operator': 'THR Hotel am Alexanderplatz Berlin Betriebs- & Management GmbH',
#       'osm_type': 'n',
#       'wikidata': 'Q111650569',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Karl-Liebknecht-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:email': 'berlin.ales@h-hotels.com',
#       'contact:phone': '+49 30 30104110',
#       'contact:website': 'https://www.h-hotels.com/de/h4/hotels/h4-hotel-berlin-alexanderplatz',
#       'internet_access': 'wlan',
#       'addr:housenumber': 32,
#       'air_conditioning': 'yes',
#       'internet_access:fee': 'no'}},
#     'distance': 310,
#     'place_id': '5196885c154dd42a4059cdcfb79745434a40f00103f90191aab4450000000092031e483420486f74656c204265726c696e2d416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.414650599999998, 52.52556129908735]}},
#   {'type': 'Feature',
#    'properties': {'name': "Flower's Boardinghause",
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10119',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Mulackstraße',
#     'housenumber': '1',
#     'lon': 13.4076704,
#     'lat': 52.5270903,
#     'formatted': "Flower's Boardinghause, Mulackstraße 1, 10119 Berlin, Germany",
#     'address_line1': "Flower's Boardinghause",
#     'address_line2': 'Mulackstraße 1, 10119 Berlin, Germany',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': "Flower's Boardinghause",
#       'osm_id': 2772307534,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'no',
#       'addr:street': 'Mulackstraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10119,
#       'addr:housenumber': 1}},
#     'distance': 356,
#     'place_id': '513018b72cbad02a4059384fe6b177434a40f00103f9014e0e3ea500000000920316466c6f776572277320426f617264696e676861757365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4076704, 52.52709029908732]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Greet Berlin Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Bernhard-Weiß-Straße',
#     'housenumber': '8',
#     'lon': 13.41617359866384,
#     'lat': 52.52371795,
#     'formatted': 'Greet Berlin Alexanderplatz, Bernhard-Weiß-Straße 8, 10178 Berlin, Germany',
#     'address_line1': 'Greet Berlin Alexanderplatz',
#     'address_line2': 'Bernhard-Weiß-Straße 8, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.limited'],
#     'details': ['details', 'details.building', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Greet Berlin Alexanderplatz',
#       'brand': 'greet',
#       'osm_id': 39496774,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'operator': 'accor',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'roof:shape': 'flat',
#       'wheelchair': 'limited',
#       'addr:street': 'Bernhard-Weiß-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'brand:wikidata': 'Q115489066',
#       'building:levels': 8,
#       'internet_access': 'wlan',
#       'addr:housenumber': 8}},
#     'distance': 381,
#     'place_id': '51993f213019d52a4059f610604509434a40f00102f90146ac5a020000000092031b4772656574204265726c696e20416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.416207794245382, 52.52372042837844]}},
#   {'type': 'Feature',
#    'properties': {'name': 'The Weinmeister',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Weinmeisterstraße',
#     'housenumber': '2',
#     'lon': 13.4044505,
#     'lat': 52.5255657,
#     'formatted': 'The Weinmeister, Weinmeisterstraße 2, 10178 Berlin, Germany',
#     'address_line1': 'The Weinmeister',
#     'address_line2': 'Weinmeisterstraße 2, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'wheelchair',
#      'wheelchair.limited'],
#     'details': ['details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'The Weinmeister',
#       'osm_id': 3780147516,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'limited',
#       'addr:street': 'Weinmeisterstraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'addr:housenumber': 2}},
#     'distance': 431,
#     'place_id': '51a2b3cc2214cf2a405963bda0bc45434a40f00103f9013c7950e10000000092030f546865205765696e6d656973746572'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4044505, 52.52556569908736]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Selina',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10119',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Alte Schönhauser Straße',
#     'housenumber': '2',
#     'lon': 13.408978195912084,
#     'lat': 52.52852075,
#     'formatted': 'Selina, Alte Schönhauser Straße 2, 10119 Berlin, Germany',
#     'address_line1': 'Selina',
#     'address_line2': 'Alte Schönhauser Straße 2, 10119 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details', 'details.building'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Selina',
#       'brand': 'Selina',
#       'osm_id': 305213424,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'addr:street': 'Alte Schönhauser Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10119,
#       'brand:wikidata': 'Q110173599',
#       'building:levels': 7,
#       'addr:housenumber': 2}},
#     'distance': 453,
#     'place_id': '51e94b56875ed12a4059a8340382a5434a40f00102f901f02f31120000000092030653656c696e61'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.408924321445697, 52.52848839909103]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hotel Casa Camper Berlin',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Weinmeisterstraße',
#     'housenumber': '1',
#     'lon': 13.4040637,
#     'lat': 52.5257861,
#     'formatted': 'Hotel Casa Camper Berlin, Weinmeisterstraße 1, 10178 Berlin, Germany',
#     'address_line1': 'Hotel Casa Camper Berlin',
#     'address_line2': 'Weinmeisterstraße 1, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel Casa Camper Berlin',
#       'osm_id': 540914067,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'wikidata': 'Q111388277',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Weinmeisterstraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+493020003410',
#       'contact:website': 'http://www.casacamper.com/berlin/',
#       'addr:housenumber': 1}},
#     'distance': 463,
#     'place_id': '516300f26fe1ce2a4059c4227af54c434a40f00103f90193b13d2000000000920318486f74656c20436173612043616d706572204265726c696e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4040637, 52.525786099087355]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hotel Indigo Berlin Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Bernhard-Weiß-Straße',
#     'housenumber': '5',
#     'lon': 13.4173768,
#     'lat': 52.5240218,
#     'formatted': 'Hotel Indigo Berlin Alexanderplatz, Bernhard-Weiß-Straße 5, 10178 Berlin, Germany',
#     'address_line1': 'Hotel Indigo Berlin Alexanderplatz',
#     'address_line2': 'Bernhard-Weiß-Straße 5, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'wheelchair',
#      'wheelchair.limited'],
#     'details': ['details', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel Indigo Berlin Alexanderplatz',
#       'brand': 'Hotel Indigo',
#       'osm_id': 1825682839,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'limited',
#       'addr:street': 'Bernhard-Weiß-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'brand:wikidata': 'Q5911596',
#       'brand:wikipedia': 'en:Hotel Indigo',
#       'addr:housenumber': 5}},
#     'distance': 469,
#     'place_id': '51df377469b2d52a405959bc742513434a40f00103f90197b5d16c00000000920322486f74656c20496e6469676f204265726c696e20416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.417376799999998, 52.5240217990874]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Soho House Berlin',
#     'old_name': 'Kaufhaus Jonaß',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10119',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Torstraße',
#     'housenumber': '1',
#     'lon': 13.415889066643155,
#     'lat': 52.527766799999995,
#     'formatted': 'Soho House Berlin, Torstraße 1, 10119 Berlin, Germany',
#     'address_line1': 'Soho House Berlin',
#     'address_line2': 'Torstraße 1, 10119 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'building.commercial',
#      'building.historic',
#      'heritage',
#      'wheelchair',
#      'wheelchair.limited'],
#     'details': ['details',
#      'details.building',
#      'details.facilities',
#      'details.heritage',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'club': 'social',
#       'name': 'Soho House Berlin',
#       'osm_id': 23278333,
#       'amenity': 'social_club',
#       'ref:lda': '09050113',
#       'tourism': 'hotel',
#       'website': 'https://www.sohohouse.com/de/houses/soho-house-berlin',
#       'building': 'retail',
#       'heritage': 4,
#       'old_name': 'Kaufhaus Jonaß',
#       'osm_type': 'w',
#       'wikidata': 'Q1504641',
#       'addr:city': 'Berlin',
#       'wikipedia': 'de:Kaufhaus Jonaß',
#       'start_date': '1927..1929',
#       'wheelchair': 'limited',
#       'addr:street': 'Torstraße',
#       'lda:criteria': 'Baudenkmal',
#       'addr:postcode': 10119,
#       'building:levels': 8,
#       'contact:website': 'https://www.sohohouseberlin.com/',
#       'addr:housenumber': 1,
#       'heritage:website': 'https://denkmaldatenbank.berlin.de/daobj.php?obj_dok_nr=09050113',
#       'heritage:operator': 'lda',
#       'wikimedia_commons': 'Category:Kaufhaus Jonaß'}},
#     'distance': 471,
#     'place_id': '512d8d79d7d4d42a40598d64b3ab8c434a40f00102f901fd32630100000000920311536f686f20486f757365204265726c696e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.415686353290392, 52.527730429262284]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Premier Inn Berlin Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Theanolte-Bähnisch-Straße',
#     'housenumber': '2',
#     'lon': 13.4174074,
#     'lat': 52.5237464,
#     'formatted': 'Premier Inn Berlin Alexanderplatz, Theanolte-Bähnisch-Straße 2, 10178 Berlin, Germany',
#     'address_line1': 'Premier Inn Berlin Alexanderplatz',
#     'address_line2': 'Theanolte-Bähnisch-Straße 2, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.for_customers',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Premier Inn Berlin Alexanderplatz',
#       'brand': 'Premier Inn',
#       'phone': '+49 30 740747',
#       'osm_id': 1825682816,
#       'tourism': 'hotel',
#       'website': 'https://www.premierinn.com/gb/en/hotels/germany/berlin/berlin/berlin-alexanderplatz.html',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Theanolte-Bähnisch-Straße',
#       'addr:postcode': 10178,
#       'brand:wikidata': 'Q2108626',
#       'brand:wikipedia': 'en:Holiday Inn',
#       'internet_access': 'yes',
#       'addr:housenumber': 2,
#       'internet_access:fee': 'customers',
#       'internet_access:ssid': 'Premier Inn Free Wi-Fi',
#       'internet_access:operator': 'Virgin Media'}},
#     'distance': 474,
#     'place_id': '517f37386cb6d52a405935bd3b1f0a434a40f00103f90180b5d16c000000009203215072656d69657220496e6e204265726c696e20416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4174074, 52.52374639908741]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Adina Apartment Hotel Berlin Hackescher Markt',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Spandauer Vorstadt',
#     'suburb': 'Mitte',
#     'street': 'An der Spandauer Brücke',
#     'housenumber': '11',
#     'lon': 13.4040319,
#     'lat': 52.5223457,
#     'formatted': 'Adina Apartment Hotel Berlin Hackescher Markt, An der Spandauer Brücke 11, 10178 Berlin, Germany',
#     'address_line1': 'Adina Apartment Hotel Berlin Hackescher Markt',
#     'address_line2': 'An der Spandauer Brücke 11, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Adina Apartment Hotel Berlin Hackescher Markt',
#       'brand': 'Adina Hotels',
#       'osm_id': 2796710200,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'wikidata': 'Q111388150',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'An der Spandauer Brücke',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+49 30 2096980',
#       'brand:wikidata': 'Q50406079',
#       'contact:website': 'https://www.adinahotels.com/en/apartments/berlin-hackescher-markt/',
#       'internet_access': 'yes',
#       'addr:housenumber': 11,
#       'toilets:wheelchair': 'yes',
#       'internet_access:fee': 'yes'}},
#     'distance': 495,
#     'place_id': '51dc14ea44ddce2a4059ba644f39dc424a40f00103f9013869b2a60000000092032d4164696e612041706172746d656e7420486f74656c204265726c696e204861636b657363686572204d61726b74'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4040319, 52.52234569908747]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Motel One',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10179',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Grunerstraße',
#     'housenumber': '11',
#     'lon': 13.41246948734898,
#     'lat': 52.5197824,
#     'formatted': 'Motel One, Grunerstraße 11, 10179 Berlin, Germany',
#     'address_line1': 'Motel One',
#     'address_line2': 'Grunerstraße 11, 10179 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.building',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Motel One',
#       'brand': 'Motel One',
#       'phone': '+493020969780',
#       'rooms': 708,
#       'branch': 'Berlin-Alexanderplatz',
#       'osm_id': 558863058,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'roof:shape': 'flat',
#       'wheelchair': 'yes',
#       'addr:street': 'Grunerstraße',
#       'addr:postcode': 10179,
#       'brand:wikidata': 'Q391080',
#       'brand:wikipedia': 'en:Motel One',
#       'building:levels': 18,
#       'contact:website': 'https://www.motel-one.com/en/hotels/berlin/hotel-berlin-alexanderplatz/',
#       'internet_access': 'wlan',
#       'addr:housenumber': 11,
#       'toilets:wheelchair': 'yes'}},
#     'distance': 501,
#     'place_id': '51968215342fd32a40592e740c3b88424a40f00102f901d2924f21000000009203094d6f74656c204f6e65'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.412469508767838, 52.51978242977235]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Alexander Plaza',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Spandauer Vorstadt',
#     'suburb': 'Mitte',
#     'street': 'Rosenstraße',
#     'housenumber': '1',
#     'lon': 13.404112295159964,
#     'lat': 52.5215991,
#     'formatted': 'Alexander Plaza, Rosenstraße 1, 10178 Berlin, Germany',
#     'address_line1': 'Alexander Plaza',
#     'address_line2': 'Rosenstraße 1, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.building', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Alexander Plaza',
#       'osm_id': 23853138,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'operator': 'Classic Hotel Collection',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Rosenstraße',
#       'addr:suburb': 'Mitte',
#       'roof:levels': 2,
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'building:levels': 5,
#       'contact:website': 'http://www.alexander-plaza.com',
#       'addr:housenumber': 1}},
#     'distance': 516,
#     'place_id': '51c7a3e391ecce2a40590e015ac9c3424a40f00102f90152f86b010000000092030f416c6578616e64657220506c617a61'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.404148634946877, 52.52159993071301]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hampton by Hilton Berlin City Centre Alexanderplatz',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'suburb': 'Mitte',
#     'street': 'Otto-Braun-Straße',
#     'housenumber': '69',
#     'lon': 13.418777915298513,
#     'lat': 52.524689800000004,
#     'formatted': 'Hampton by Hilton Berlin City Centre Alexanderplatz, Otto-Braun-Straße 69, 10178 Berlin, Germany',
#     'address_line1': 'Hampton by Hilton Berlin City Centre Alexanderplatz',
#     'address_line2': 'Otto-Braun-Straße 69, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.accommodation',
#      'details.building',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'fax': '+49-30-21308551',
#       'name': 'Hampton by Hilton Berlin City Centre Alexanderplatz',
#       'brand': 'Hampton',
#       'email': 'info@hamptonberlin-alex.de',
#       'phone': '+49-30-21308555',
#       'rooms': 344,
#       'stars': 3,
#       'osm_id': 464524861,
#       'tourism': 'hotel',
#       'website': 'https://www.hilton.com/en/hotels/berhxhx-hampton-berlin-city-centre-alexanderplatz/?WT.mc_id=zDA0DE1HP2DMH3LocalSearch4DGGeneric_Apr56BERHXHX7EN8i1',
#       'alt_name': 'Hampton Inn',
#       'building': 'hotel',
#       'operator': 'Hilton',
#       'osm_type': 'w',
#       'wikidata': 'Q73499085',
#       'addr:city': 'Berlin',
#       'roof:shape': 'flat',
#       'wheelchair': 'yes',
#       'addr:street': 'Otto-Braun-Straße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'official_name': 'Hampton by Hilton',
#       'brand:wikidata': 'Q5646230',
#       'brand:wikipedia': 'en:Hampton by Hilton',
#       'building:levels': 9,
#       'internet_access': 'wlan',
#       'addr:housenumber': 69,
#       'contact:facebook': 'https://www.facebook.com/HbHAlexanderplatz',
#       'wikimedia_commons': 'Category:Hampton by Hilton Berlin Alexanderplatz'}},
#     'distance': 533,
#     'place_id': '51faedf7616ed62a405959e9c2682d434a40f00102f9013d16b01b0000000092033348616d70746f6e2062792048696c746f6e204265726c696e20436974792043656e74726520416c6578616e646572706c61747a'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.418810903086513, 52.524823279544485]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hotel Hackescher Markt',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Spandauer Vorstadt',
#     'suburb': 'Mitte',
#     'street': 'Große Präsidentenstraße',
#     'housenumber': '8',
#     'lon': 13.4012754,
#     'lat': 52.5232037,
#     'formatted': 'Hotel Hackescher Markt, Große Präsidentenstraße 8, 10178 Berlin, Germany',
#     'address_line1': 'Hotel Hackescher Markt',
#     'address_line2': 'Große Präsidentenstraße 8, 10178 Berlin, Germany',
#     'categories': ['accommodation', 'accommodation.hotel'],
#     'details': ['details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel Hackescher Markt',
#       'osm_id': 2776767374,
#       'tourism': 'hotel',
#       'osm_type': 'n',
#       'addr:city': 'Berlin',
#       'wheelchair': 'no',
#       'addr:street': 'Große Präsidentenstraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10178,
#       'contact:phone': '+493025002385',
#       'addr:housenumber': 8}},
#     'distance': 640,
#     'place_id': '51ee601ff873cd2a4059045dbc56f8424a40f00103f9018e1b82a500000000920316486f74656c204861636b657363686572204d61726b74'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.4012754, 52.52320369908742]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hotel ZOE',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10178',
#     'district': 'Mitte',
#     'neighbourhood': 'Spandauer Vorstadt',
#     'suburb': 'Mitte',
#     'street': 'Große Präsidentenstraße',
#     'lon': 13.400940407516972,
#     'lat': 52.5230518,
#     'formatted': 'Hotel ZOE, Große Präsidentenstraße, 10178 Berlin, Germany',
#     'address_line1': 'Hotel ZOE',
#     'address_line2': 'Große Präsidentenstraße, 10178 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details', 'details.building', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel ZOE',
#       'osm_id': 272748506,
#       'tourism': 'hotel',
#       'website': 'http://www.amanogroup.de/en/hotels/hotel-zoe/',
#       'building': 'yes',
#       'operator': 'Amano Group',
#       'osm_type': 'w',
#       'wheelchair': 'yes',
#       'building:levels': 7}},
#     'distance': 644,
#     'place_id': '510122ed2a4bcd2a405909ba5dcaf3424a40f00102f901dacf411000000000920309486f74656c205a4f45'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.400964108893278, 52.52306489540576]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hotel Amano',
#     'country': 'Germany',
#     'country_code': 'de',
#     'city': 'Berlin',
#     'postcode': '10119',
#     'district': 'Mitte',
#     'neighbourhood': 'Scheunenviertel',
#     'suburb': 'Mitte',
#     'street': 'Auguststraße',
#     'housenumber': '43',
#     'lon': 13.402855995082255,
#     'lat': 52.528251499999996,
#     'formatted': 'Hotel Amano, Auguststraße 43, 10119 Berlin, Germany',
#     'address_line1': 'Hotel Amano',
#     'address_line2': 'Auguststraße 43, 10119 Berlin, Germany',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details',
#      'details.building',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel Amano',
#       'osm_id': 105210648,
#       'tourism': 'hotel',
#       'building': 'hotel',
#       'operator': 'R & S Hotelbetriebsgesellschaft',
#       'osm_type': 'w',
#       'addr:city': 'Berlin',
#       'wheelchair': 'yes',
#       'addr:street': 'Auguststraße',
#       'addr:suburb': 'Mitte',
#       'addr:country': 'DE',
#       'addr:postcode': 10119,
#       'contact:phone': '+49 30 8094150',
#       'building:levels': 5,
#       'contact:website': 'http://www.hotel-amano.com/',
#       'addr:housenumber': 43}},
#     'distance': 653,
#     'place_id': '5107c371d042ce2a40599f3bd1259e434a40f00102f901186345060000000092030b486f74656c20416d616e6f'},
#    'geometry': {'type': 'Point',
#     'coordinates': [13.402853502165739, 52.52826378551912]}}]}

# %%
print(name_address["type"][])
# Out:
# e

# %%
name_address["features"][0]["properties"]["name"]
# Out:
# 'Lux 11'

# %%
name_address["features"][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry'])
